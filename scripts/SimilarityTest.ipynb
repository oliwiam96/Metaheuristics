# %%
import matplotlib.pyplot as plt
import csv

greedy_distance = []
greedy_score = []
steepest_distance = []
steepest_score = []

with open("../Results/Similarity/code253.csv",'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        greedy_distance.append(float(row[0]))
        greedy_score.append(float(row[1]))
        steepest_distance.append(float(row[2]))
        steepest_score.append(float(row[3]))

plt.rcParams['figure.figsize'] = [10, 5]
plt.scatter(greedy_score, greedy_distance, marker='o', label="greedy")
plt.scatter(steepest_score, steepest_distance, marker='v', label="steepest")

plt.legend(loc='lower right')
plt.ylim(top = 0.35, bottom=0.2)
plt.xlabel('jakość rozwiązania')
plt.ylabel('podobieństwo do najlepszego rozwiązania')
plt.savefig('similarity_bi.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

greedy_distance = []
greedy_score = []
steepest_distance = []
steepest_score = []

with open("../Results/Similarity/atex1.csv",'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        greedy_distance.append(float(row[0]))
        greedy_score.append(float(row[1]))
        steepest_distance.append(float(row[2]))
        steepest_score.append(float(row[3]))
plt.rcParams['figure.figsize'] = [10, 5]
plt.scatter(greedy_score, greedy_distance, marker='o', label="greedy")
plt.scatter(steepest_score, steepest_distance, marker='v', label="steepest")
plt.legend(loc='lower right')

plt.xlabel('jakość rozwiązania')
plt.ylabel('podobieństwo do najlepszego rozwiązania')
plt.savefig('similarity_small.pdf')
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.rcParams['figure.figsize'] = [15, 5]


greedy_distance = []
greedy_score = []


with open("../Results/Similarity/fromH_atex1.csv",'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        greedy_distance.append(float(row[0]))
        greedy_score.append(float(row[1]))

ax1.scatter(greedy_score, greedy_distance, marker='o')
ax1.set_xlabel('Greedy from H')
ax1.set_ylabel('podobieństwo do najlepszego rozwiązania')


greedy_distance = []
greedy_score = []


with open("../Results/Similarity/fromAntiH_atex1.csv",'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        greedy_distance.append(float(row[0]))
        greedy_score.append(float(row[1]))

ax2.scatter(greedy_score, greedy_distance, marker='o')
ax2.set_xlabel('Greedy from anty H')

greedy_distance = []
greedy_score = []


with open("../Results/Similarity/onlyH_atex1.csv",'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        greedy_distance.append(float(row[0]))
        greedy_score.append(float(row[1]))

ax3.scatter(greedy_score, greedy_distance, marker='o')
ax3.set_xlabel('Only Heuristic H')
plt.savefig('similarity_3.pdf')
plt.show()
